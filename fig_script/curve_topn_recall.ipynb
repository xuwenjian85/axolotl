# %%
import sys
import os
import subprocess
import pandas as pd
import numpy as np
import tempfile
import yaml

import warnings
warnings.filterwarnings("ignore", category=FutureWarning)
warnings.filterwarnings("ignore", category=DeprecationWarning)

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from statannotations.Annotator import Annotator

import os

from datetime import date
print(date.today())
# conda install mkl-service mkl
import mkl
nCPU= 20
N=4
# Out:
# 2025-11-26

# %%
# 准备结果目录和流程所需config文件
# level 1
workdir = '/mnt/disk7t/xwj/axolotl_rev/'
#'kremer' # kremer_random'  # gtex_nmd 
title = 'pfib_423'  
# title = 'pmuscle_36'
if title == 'gtex_nmd': # GTEx nmd
    output_path = f'{workdir}/result/dataset_gtex_nmd'
    tissues = pd.read_csv(f'{workdir}/gtex_processed/tissues.tsv', sep='\t', index_col=0)
    # tissues = tissues.query('N_SAMPLE < 150')#.reset_index(drop=True)
    
elif title == 'kremer':
    output_path = f'{workdir}/result/dataset_nc2017kremer'
    datasetdir = f'{workdir}/dataset_nc2017kremer'
    tissues = pd.read_csv(f'{datasetdir}/tissues.tsv', sep='\t', index_col=0)
    
elif title == 'pfib_423':
    output_path = f'{workdir}/result/dataset_pfib_423_split'
    datasetdir = f'{workdir}/pfib_423_processed' 
    use ='split'
    tissues = pd.read_csv(f'{datasetdir}/tissues_{use}.tsv', sep='\t', index_col=0)
    phase =''
    outlier_sample_col = 'Sample'
    outlier_gene_col = 'Gene'
    
elif title == 'pmuscle_36':
    output_path = f'{workdir}/result/dataset_pmuscle_36'
    datasetdir = f'{workdir}/pmuscle_36_processed' 
    use = 'pmuscle36' # 13k gene min 10 reads
    use = 'pmuscle36_0'
    tissues = pd.read_csv(f'{datasetdir}/tissues_{use}.tsv', sep='\t', index_col=0)
    phase =''
    outlier_sample_col = 'Sample'
    outlier_gene_col = 'Gene' 
else:
    pass
# level 2
samples_path = f'{output_path}/samples'
task_config_path = f'{output_path}/task_config'
task_output_path = f'{output_path}/task_output'
metric_output_path = f'{output_path}/metric'
print(samples_path)
tissues.head()
# Out:
# /mnt/disk7t/xwj/axolotl_rev//result/dataset_pfib_423_split/samples
#   TISSUE_ID             TISSUE_NAME  N_SAMPLE  N_GENE  \
# 0      FBSS     Fibroblast_Stranded       269   12369
# 1      FBNS  Fibroblast_NonStranded       154   13411
#
#                                             CTS_FILE  \
# 0  /mnt/disk7t/xwj/axolotl_rev/pfib_423_processed...
# 1  /mnt/disk7t/xwj/axolotl_rev/pfib_423_processed...
#
#                                         OUTLIER_FILE
# 0  /mnt/disk7t/xwj/axolotl_rev/pfib_423_processed...
# 1  /mnt/disk7t/xwj/axolotl_rev/pfib_423_processed...

# %%
# methods = [ 'OUTRIDER', 'OUTSINGLE', 'MyMethod']
baselines = [ 'OUTRIDER', 'OUTSINGLE', 'ABEILLE' ]
abl_scores = ['anomaly_score', 'delta_count', 'divergence_score']
outrider_scores = [ 'pValue', 'zScore','padjust']
outrider_scores = [ 'padjust']
baselines = [ f'{m}_{score}' for m in ['OUTRIDER', 'ABEILLE'] for score in (outrider_scores if m=='OUTRIDER' else abl_scores) ] + ['OUTSINGLE']

mymethods = [ f'f{i}{md}' for i in list(range(20,24)) for md in ['L','I','O']] 
mymethods = [ f'{f}{m}' for f in ['f0', 'f0.05','f0.1','f0.2', 'f0.5','f1', 'f2','f4'] 
             for m in ['L10', 'L20','L30', 'L40'] ]
# mymethods = [ f'{f}{m}' for f in ['f0', 'f0.05','f0.1','f0.2', 'f0.5','f1', 'f2','f4'] for m in [ 'L30', ] ]
mymethods = [ f'{f}{m}' for f in ['f0.1', ] 
             for m in ['L20',] ]
methods = baselines + mymethods
# methods = ['OUTSINGLE', ] + mymethods

num = 49
print(num, phase, methods)
# Out:
# 49  ['OUTRIDER_padjust', 'ABEILLE_anomaly_score', 'ABEILLE_delta_count', 'ABEILLE_divergence_score', 'OUTSINGLE', 'f0.1L20']

# %%
## topn recall

def pivot_sort_score_outlier_rank(res_data, score_col, gene_col, sample_col, df_outlier):
    """
    计算ABEILLE方法单个打分方式的AUPRC
    参数:
        res_data: 包含预测结果的DataFrame
        score_col: 用于排序的打分列名
        df_outlier: 包含真实异常的DataFrame
    """
    # 按predict和score排序
    ascend = score_order[ score_col ]
    sorted_data = res_data.pivot_table(columns=sample_col, index=gene_col, values=score_col).rank(ascending=ascend, method='first')
    outlier_rank = [ sorted_data.loc[g,s] for g,s in zip(df_outlier['Gene'], df_outlier['Sample'])]
    new_df_outlier = df_outlier.copy() # must make a copy
    new_df_outlier['rank'] = outlier_rank
    return new_df_outlier

def sort_score_outlier_rank(res_data, df_outlier, ascend=True):
    sorted_data = res_data.rank(ascending=ascend, method='first')
    outlier_rank = [ sorted_data.loc[g,s] for g,s in zip(df_outlier['Gene'], df_outlier['Sample'])]
    new_df_outlier = df_outlier.copy() # must make a copy
    new_df_outlier['rank'] = outlier_rank
    return new_df_outlier

# %%
methods = ['OUTRIDER_padjust',
 'ABEILLE_anomaly_score',
 'ABEILLE_delta_count',
 'ABEILLE_divergence_score',
 'OUTSINGLE',
 'f0.1L20',
]

from tqdm import tqdm
# 为兼容以后的子集抽样，需要定义保存不同抽样方案的outlier
dict_outlier_setting = dict()
dict_outlier_setting['all'] = {} 

# 定义排序逻辑
score_order = {
    'anomaly_score': False,
    'delta_count': True,
    'divergence_score': True,
    'pValue': True,
    'padjust': True,
    'zScore': True,
}


## 分析一个完整dataset，不带子集抽样
for i, row in tissues.iterrows():
    # --> level 1. one tissue
    t  = row.TISSUE_ID
    tn = row.TISSUE_NAME
    ns = row.N_SAMPLE
    ng = row.N_GENE
    ctsfile = row.CTS_FILE
    outlierfile = row.OUTLIER_FILE
    
    dict_res = dict()
    dict_auprc = dict()
    dict_curve = dict()
    
    for k in dict_outlier_setting.keys():
        # --> level 2. (tissue, task) one tissue have many tasks
        if k == 'all':
            prefix = f't{i:02d}_{t}_s{ns}_g{ng}' # id, number of samples, number of genes.
        else:
            pass # todo, add some change to prefix
        
        # 读入任务
        task_config = pd.read_csv(f'{task_config_path}/{prefix}.config', sep='\t')
        samples = pd.read_csv(f'{samples_path}/{prefix}.txt', sep='\t',index_col='task')
        # all outlier
        # outliers_used = pd.read_csv(f'{samples_path}/{prefix}_outliers.txt', sep='\t',index_col=0)
        # valid split
        outliers_used = pd.read_csv(outlierfile.replace('.tsv', f'{phase}.tsv'), sep='\t',index_col=0)
        print(prefix, samples.shape, outliers_used.shape)

        if 'Sample' in outliers_used.columns:
            df_outlier = outliers_used
        else:
            outlier_sample_col = 'SAMPLE_ID'
            outlier_gene_col = 'Gene'
            df_outlier = outliers_used.rename(columns={outlier_sample_col:'Sample', outlier_gene_col:'Gene'})
        
        for m in methods:
            # ==> level 3. (tissue, task, method)
            dict_res = dict()
            dict_auprc = dict()
            dict_curve = dict()
            
            for j,row in task_config.iterrows():
                # ==> level 4. (tissue, task, method)
                if m.startswith('ABEILLE'):
                    method, score_col = m.split('_',1)
                    print(method, score_col)
                    res_data = pd.read_csv(f"{row[method]}_raw.gz", sep='\t',index_col=0)
                    res_data.index = [(s,g) for s,g in zip(res_data['Sample'], res_data['Transcript'])]
                    class_col = 'predict'
                    gene_col = 'Transcript'
                    sample_col = 'Sample'
                    dict_curve[j] = pivot_sort_score_outlier_rank(res_data, score_col, gene_col, sample_col, df_outlier)
                                                   
                elif m.startswith('OUTRIDER'):
                    method, score_col = m.split('_',1)
                    print(method, score_col)
                    res_data = pd.read_csv(f"{row[method]}_raw.gz", sep='\t',index_col=0)
                    res_data.index = [(s,g) for s,g in zip(res_data['sampleID'], res_data['geneID'])]
                    class_col = 'aberrant'
                    gene_col = 'geneID'
                    sample_col = 'sampleID'
                    dict_curve[j] = pivot_sort_score_outlier_rank(res_data, score_col, gene_col, sample_col, df_outlier)

                elif m == 'OUTSINGLE':
                    print(m)
                    df_pred = pd.read_csv(f"{row[m]}", sep='\t',index_col=0)
                    dict_curve[j] = sort_score_outlier_rank(df_pred, df_outlier)

                else: # my method
                    print(m)
                    df_pred = pd.read_csv(f'{row['MyMethod']}_res_{m}.txt.gz', sep='\t',index_col=0)
                    dict_curve[j] = sort_score_outlier_rank(df_pred, df_outlier)

    
            # m is done,
            file = f'{metric_output_path}/{prefix}_{m}_rank{phase}.pkl' # one tissue One method   
            outputdata = [ t, tn, i, dict_curve ]
            
            import pickle
            with open(file, 'wb') as f: 
                pickle.dump( outputdata,  f )
# Out:
# t00_FBSS_s269_g12369 (1, 269) (25, 5)
# OUTRIDER padjust
# ABEILLE anomaly_score
# ABEILLE delta_count
# ABEILLE divergence_score
# OUTSINGLE
# f0.1L20
# t01_FBNS_s154_g13411 (1, 154) (24, 5)
# OUTRIDER padjust
# ABEILLE anomaly_score
# ABEILLE delta_count
# ABEILLE divergence_score
# OUTSINGLE
# f0.1L20

# %%
draw_methods = methods
plt.style.use('default')
fig, axes = plt.subplots(len(tissues), 1, figsize=(5, 5))
# pd.DataFrame(index=tissues.index, columns=draw_methods)

for i, row in tissues.iterrows():
    t  = row.TISSUE_ID
    tn = row.TISSUE_NAME
    ns = row.N_SAMPLE
    ng = row.N_GENE
    ctsfile = row.CTS_FILE
    outlierfile = row.OUTLIER_FILE
    
    k = 'all'
    dict_curve[k],dict_auprc[k] = dict(),dict()
    if k == 'all':
        prefix = f't{i:02d}_{t}_s{ns}_g{ng}' # id, number of samples, number of genes.
        
    for m in draw_methods:
        
        file = f'{metric_output_path}/{prefix}_{m}_rank{phase}.pkl' # one tissue One method
        with open(file,'rb') as f:
            data_load = pickle.load(f)
            print(tn, m)
        _t, _tn, _i, dict_curve[k][m] = data_load[0], data_load[1], data_load[2], data_load[3]
        
    # print(t, tn, i,file)

    required_sets = 1
    max_bin = 50
    bins = list(range(0, max_bin + 1)) + [20000]
    nice_names = list(range(1,max_bin + 1))+[20000]#[ f'{x}%' for x in bins[:-1]]
    
    draw = \
    pd.concat( [ 
            pd.concat( [ (dict_curve[k][m][j]['rank'].value_counts(bins= bins, sort=False)) for j in range(required_sets)], axis=0, keys=range(required_sets))
        for m in draw_methods ], axis=0, keys=draw_methods, names=['method']).reset_index()
    
    # sns.lineplot(data=draw, x="recall", y="precision", hue="level_0", palette='tab10', alpha=0.8, ax= axes[i])
    # axes[i].set_title(f'{title}(n={ns})')
    # auprc.loc[i,:] = [ dict_auprc['all'][m][0] for m in draw_methods ]

    draw['rank'] = nice_names * len(draw_methods)
    draw = draw.query('rank < 10000')
    draw['recall'] = draw.groupby('method')['count'].cumsum()/len(df_outlier)

    sns.lineplot(data=draw, x='rank', y="recall", hue="method", palette='tab10', ax=axes[i])
    axes[i].set_title(f'tissue: {t}')
        # 1. 去掉子图自己的图例
    axes[i].get_legend().remove()

# 2. 用最后一根轴的“handles/labels”生成 Figure 级图例
handles, labels = axes[-1].get_legend_handles_labels()
fig.legend(handles, labels,
        loc='center',           # 居中
        bbox_to_anchor=(0.5, 0),  # 放在底部（微调 0.02）
        ncol=len(labels),       # 横向排列
        frameon=True)
plt.tight_layout()
# Out:
# Fibroblast_Stranded OUTRIDER_padjust
# Fibroblast_Stranded ABEILLE_anomaly_score
# Fibroblast_Stranded ABEILLE_delta_count
# Fibroblast_Stranded ABEILLE_divergence_score
# Fibroblast_Stranded OUTSINGLE
# Fibroblast_Stranded f0.1L20
# Fibroblast_NonStranded OUTRIDER_padjust
# Fibroblast_NonStranded ABEILLE_anomaly_score
# Fibroblast_NonStranded ABEILLE_delta_count
# Fibroblast_NonStranded ABEILLE_divergence_score
# Fibroblast_NonStranded OUTSINGLE
# Fibroblast_NonStranded f0.1L20

# %%
# 子集抽样
n_replicates = 10  # 每个样本量重复10次
random_seeds = range(n_replicates) # 使用0-9作为随机种子

sample_sizes = [ 10, 30, 60, 100, ]

for i, tissue_data in tissues.iterrows():
    # tissue_data = tissues.iloc[0]
    t = tissue_data['TISSUE_ID']  # TISSUE_ID
    tn = tissue_data['TISSUE_NAME']  # TISSUE_NAME
    ns = tissue_data['N_SAMPLE']  # N_SAMPLE
    ng = tissue_data['N_GENE']  # N_GENE
    ctsfile = tissue_data['CTS_FILE']  # CTS_FILE
    outlierfile = tissue_data['OUTLIER_FILE']  # OUTLIER_FILE
    
    # 创建基础前缀
    name_prefix = f't{i:02d}_{t}_s{ns}_g{ng}' # id, number of samples, number of genes.
    
    # positive samples
    outlier = pd.read_csv(outlierfile.replace('.tsv', f'{phase}.tsv'), sep='\t', index_col=0)
    assert outlier['Sample'].size == len(set(outlier['Sample']))
    outliers_used = outlier.copy()

    output_file = f'{task_config_path}/{name_prefix}_sampled_configs_dict.pkl'
    sampled_configs = pickle.load(open(output_file, 'rb'))

    for size in sample_sizes:
        
        dict_res = dict() # size
        dict_curve = dict()
        
        for seed in range(n_replicates):
            k = seed
            dict_res[k] = dict() # 10 seeds 
            dict_curve[k] = dict()
            # 获取当前抽样的配置
            current_config = sampled_configs[f'size_{size}'][f'seed_{seed}']
            task_config = current_config['config']
            samples_used = current_config['selected_samples']
            df_outlier = outliers_used.query('(Sample in @samples_used)').copy()
            
            for m in methods:
                # ==> level 3. (tissue, task, method)
                print(size, seed, m)
                dict_curve[k][m] = dict()
                for j,row in task_config.iterrows():
                    if m.startswith('ABEILLE'):
                        method, score_col = m.split('_',1)
                        res_data = pd.read_csv(f"{row[method]}_raw.gz", sep='\t',index_col=0)
                        res_data.index = [(s,g) for s,g in zip(res_data['Sample'], res_data['Transcript'])]
                        class_col = 'predict'
                        gene_col = 'Transcript'
                        sample_col = 'Sample'
                        dict_curve[k][m][j] = pivot_sort_score_outlier_rank(res_data, score_col, gene_col, sample_col, df_outlier)
                                
                    elif m.startswith('OUTRIDER'):
                        method, score_col = m.split('_',1)
                        res_data = pd.read_csv(f"{row[method]}_raw.gz", sep='\t',index_col=0)
                        res_data.index = [(s,g) for s,g in zip(res_data['sampleID'], res_data['geneID'])]
                        class_col = 'aberrant'
                        gene_col = 'geneID'
                        sample_col = 'sampleID'
                        dict_curve[k][m][j] = pivot_sort_score_outlier_rank(res_data, score_col, gene_col, sample_col, df_outlier)
                    
                    elif m == 'OUTSINGLE':
                        df_pred = pd.read_csv(f"{row[m]}", sep='\t',index_col=0)
                        dict_curve[k][m][j] = sort_score_outlier_rank(df_pred, df_outlier)  
                                                  
                    else: # my method
                        df_pred = pd.read_csv(f'{row['MyMethod']}_res_{m}.txt.gz', sep='\t',index_col=0)
                        dict_curve[k][m][j] = sort_score_outlier_rank(df_pred, df_outlier)
                                                        
        file = f'{metric_output_path}/{name_prefix}_size_{size}_rank{phase}.pkl'
        outputdata = [ t, tn, i, dict_curve ]
        import pickle
        with open(file, 'wb') as f: 
            pickle.dump( outputdata,  f )
# Out:
# 10 0 OUTRIDER_padjust
# 10 0 ABEILLE_anomaly_score
# 10 0 ABEILLE_delta_count
# 10 0 ABEILLE_divergence_score
# 10 0 OUTSINGLE
# 10 0 f0.1L20
# 10 1 OUTRIDER_padjust
# 10 1 ABEILLE_anomaly_score
# 10 1 ABEILLE_delta_count
# 10 1 ABEILLE_divergence_score
# 10 1 OUTSINGLE
# 10 1 f0.1L20
# 10 2 OUTRIDER_padjust
# 10 2 ABEILLE_anomaly_score
# 10 2 ABEILLE_delta_count
# 10 2 ABEILLE_divergence_score
# 10 2 OUTSINGLE
# 10 2 f0.1L20
# 10 3 OUTRIDER_padjust
# 10 3 ABEILLE_anomaly_score
# 10 3 ABEILLE_delta_count
# 10 3 ABEILLE_divergence_score
# 10 3 OUTSINGLE
# 10 3 f0.1L20
# 10 4 OUTRIDER_padjust
# 10 4 ABEILLE_anomaly_score
# 10 4 ABEILLE_delta_count
# 10 4 ABEILLE_divergence_score
# 10 4 OUTSINGLE
# 10 4 f0.1L20
# 10 5 OUTRIDER_padjust
# 10 5 ABEILLE_anomaly_score
# 10 5 ABEILLE_delta_count
# 10 5 ABEILLE_divergence_score
# 10 5 OUTSINGLE
# 10 5 f0.1L20
# 10 6 OUTRIDER_padjust
# 10 6 ABEILLE_anomaly_score
# 10 6 ABEILLE_delta_count
# 10 6 ABEILLE_divergence_score
# 10 6 OUTSINGLE
# 10 6 f0.1L20
# 10 7 OUTRIDER_padjust
# 10 7 ABEILLE_anomaly_score
# 10 7 ABEILLE_delta_count
# 10 7 ABEILLE_divergence_score
# 10 7 OUTSINGLE
# 10 7 f0.1L20
# 10 8 OUTRIDER_padjust
# 10 8 ABEILLE_anomaly_score
# 10 8 ABEILLE_delta_count
# 10 8 ABEILLE_divergence_score
# 10 8 OUTSINGLE
# 10 8 f0.1L20
# 10 9 OUTRIDER_padjust
# 10 9 ABEILLE_anomaly_score
# 10 9 ABEILLE_delta_count
# 10 9 ABEILLE_divergence_score
# 10 9 OUTSINGLE
# 10 9 f0.1L20
# 30 0 OUTRIDER_padjust
# 30 0 ABEILLE_anomaly_score
# 30 0 ABEILLE_delta_count
# 30 0 ABEILLE_divergence_score
# 30 0 OUTSINGLE
# 30 0 f0.1L20
# 30 1 OUTRIDER_padjust
# 30 1 ABEILLE_anomaly_score
# 30 1 ABEILLE_delta_count
# 30 1 ABEILLE_divergence_score
# 30 1 OUTSINGLE
# 30 1 f0.1L20
# 30 2 OUTRIDER_padjust
# 30 2 ABEILLE_anomaly_score
# 30 2 ABEILLE_delta_count
# 30 2 ABEILLE_divergence_score
# 30 2 OUTSINGLE
# 30 2 f0.1L20
# 30 3 OUTRIDER_padjust
# 30 3 ABEILLE_anomaly_score
# 30 3 ABEILLE_delta_count
# 30 3 ABEILLE_divergence_score
# 30 3 OUTSINGLE
# 30 3 f0.1L20
# 30 4 OUTRIDER_padjust
# 30 4 ABEILLE_anomaly_score
# 30 4 ABEILLE_delta_count
# 30 4 ABEILLE_divergence_score
# 30 4 OUTSINGLE
# 30 4 f0.1L20
# 30 5 OUTRIDER_padjust
# 30 5 ABEILLE_anomaly_score
# 30 5 ABEILLE_delta_count
# 30 5 ABEILLE_divergence_score
# 30 5 OUTSINGLE
# 30 5 f0.1L20
# 30 6 OUTRIDER_padjust
# 30 6 ABEILLE_anomaly_score
# 30 6 ABEILLE_delta_count
# 30 6 ABEILLE_divergence_score
# 30 6 OUTSINGLE
# 30 6 f0.1L20
# 30 7 OUTRIDER_padjust
# 30 7 ABEILLE_anomaly_score
# 30 7 ABEILLE_delta_count
# 30 7 ABEILLE_divergence_score
# 30 7 OUTSINGLE
# 30 7 f0.1L20
# 30 8 OUTRIDER_padjust
# 30 8 ABEILLE_anomaly_score
# 30 8 ABEILLE_delta_count
# 30 8 ABEILLE_divergence_score
# 30 8 OUTSINGLE
# 30 8 f0.1L20
# 30 9 OUTRIDER_padjust
# 30 9 ABEILLE_anomaly_score
# 30 9 ABEILLE_delta_count
# 30 9 ABEILLE_divergence_score
# 30 9 OUTSINGLE
# 30 9 f0.1L20
# 60 0 OUTRIDER_padjust
# 60 0 ABEILLE_anomaly_score
# 60 0 ABEILLE_delta_count
# 60 0 ABEILLE_divergence_score
# 60 0 OUTSINGLE
# 60 0 f0.1L20
# 60 1 OUTRIDER_padjust
# 60 1 ABEILLE_anomaly_score
# 60 1 ABEILLE_delta_count
# 60 1 ABEILLE_divergence_score
# 60 1 OUTSINGLE
# 60 1 f0.1L20
# 60 2 OUTRIDER_padjust
# 60 2 ABEILLE_anomaly_score
# 60 2 ABEILLE_delta_count
# 60 2 ABEILLE_divergence_score
# 60 2 OUTSINGLE
# 60 2 f0.1L20
# 60 3 OUTRIDER_padjust
# 60 3 ABEILLE_anomaly_score
# 60 3 ABEILLE_delta_count
# 60 3 ABEILLE_divergence_score
# 60 3 OUTSINGLE
# 60 3 f0.1L20
# 60 4 OUTRIDER_padjust
# 60 4 ABEILLE_anomaly_score
# 60 4 ABEILLE_delta_count
# 60 4 ABEILLE_divergence_score
# 60 4 OUTSINGLE
# 60 4 f0.1L20
# 60 5 OUTRIDER_padjust
# 60 5 ABEILLE_anomaly_score
# 60 5 ABEILLE_delta_count
# 60 5 ABEILLE_divergence_score
# 60 5 OUTSINGLE
# 60 5 f0.1L20
# 60 6 OUTRIDER_padjust
# 60 6 ABEILLE_anomaly_score
# 60 6 ABEILLE_delta_count
# 60 6 ABEILLE_divergence_score
# 60 6 OUTSINGLE
# 60 6 f0.1L20
# 60 7 OUTRIDER_padjust
# 60 7 ABEILLE_anomaly_score
# 60 7 ABEILLE_delta_count
# 60 7 ABEILLE_divergence_score
# 60 7 OUTSINGLE
# 60 7 f0.1L20
# 60 8 OUTRIDER_padjust
# 60 8 ABEILLE_anomaly_score
# 60 8 ABEILLE_delta_count
# 60 8 ABEILLE_divergence_score
# 60 8 OUTSINGLE
# 60 8 f0.1L20
# 60 9 OUTRIDER_padjust
# 60 9 ABEILLE_anomaly_score
# 60 9 ABEILLE_delta_count
# 60 9 ABEILLE_divergence_score
# 60 9 OUTSINGLE
# 60 9 f0.1L20
# 100 0 OUTRIDER_padjust
# 100 0 ABEILLE_anomaly_score
# 100 0 ABEILLE_delta_count
# 100 0 ABEILLE_divergence_score
# 100 0 OUTSINGLE
# 100 0 f0.1L20
# 100 1 OUTRIDER_padjust
# 100 1 ABEILLE_anomaly_score
# 100 1 ABEILLE_delta_count
# 100 1 ABEILLE_divergence_score
# 100 1 OUTSINGLE
# 100 1 f0.1L20
# 100 2 OUTRIDER_padjust
# 100 2 ABEILLE_anomaly_score
# 100 2 ABEILLE_delta_count
# 100 2 ABEILLE_divergence_score
# 100 2 OUTSINGLE
# 100 2 f0.1L20
# 100 3 OUTRIDER_padjust
# 100 3 ABEILLE_anomaly_score
# 100 3 ABEILLE_delta_count
# 100 3 ABEILLE_divergence_score
# 100 3 OUTSINGLE
# 100 3 f0.1L20
# 100 4 OUTRIDER_padjust
# 100 4 ABEILLE_anomaly_score
# 100 4 ABEILLE_delta_count
# 100 4 ABEILLE_divergence_score
# 100 4 OUTSINGLE
# 100 4 f0.1L20
# 100 5 OUTRIDER_padjust
# 100 5 ABEILLE_anomaly_score
# 100 5 ABEILLE_delta_count
# 100 5 ABEILLE_divergence_score
# 100 5 OUTSINGLE
# 100 5 f0.1L20
# 100 6 OUTRIDER_padjust
# 100 6 ABEILLE_anomaly_score
# 100 6 ABEILLE_delta_count
# 100 6 ABEILLE_divergence_score
# 100 6 OUTSINGLE
# 100 6 f0.1L20
# 100 7 OUTRIDER_padjust
# 100 7 ABEILLE_anomaly_score
# 100 7 ABEILLE_delta_count
# 100 7 ABEILLE_divergence_score
# 100 7 OUTSINGLE
# 100 7 f0.1L20
# 100 8 OUTRIDER_padjust
# 100 8 ABEILLE_anomaly_score
# 100 8 ABEILLE_delta_count
# 100 8 ABEILLE_divergence_score
# 100 8 OUTSINGLE
# 100 8 f0.1L20
# 100 9 OUTRIDER_padjust
# 100 9 ABEILLE_anomaly_score
# 100 9 ABEILLE_delta_count
# 100 9 ABEILLE_divergence_score
# 100 9 OUTSINGLE
# 100 9 f0.1L20
# 10 0 OUTRIDER_padjust
# 10 0 ABEILLE_anomaly_score
# 10 0 ABEILLE_delta_count
# 10 0 ABEILLE_divergence_score
# 10 0 OUTSINGLE
# 10 0 f0.1L20
# 10 1 OUTRIDER_padjust
# 10 1 ABEILLE_anomaly_score
# 10 1 ABEILLE_delta_count
# 10 1 ABEILLE_divergence_score
# 10 1 OUTSINGLE
# 10 1 f0.1L20
# 10 2 OUTRIDER_padjust
# 10 2 ABEILLE_anomaly_score
# 10 2 ABEILLE_delta_count
# 10 2 ABEILLE_divergence_score
# 10 2 OUTSINGLE
# 10 2 f0.1L20
# 10 3 OUTRIDER_padjust
# 10 3 ABEILLE_anomaly_score
# 10 3 ABEILLE_delta_count
# 10 3 ABEILLE_divergence_score
# 10 3 OUTSINGLE
# 10 3 f0.1L20
# 10 4 OUTRIDER_padjust
# 10 4 ABEILLE_anomaly_score
# 10 4 ABEILLE_delta_count
# 10 4 ABEILLE_divergence_score
# 10 4 OUTSINGLE
# 10 4 f0.1L20
# 10 5 OUTRIDER_padjust
# 10 5 ABEILLE_anomaly_score
# 10 5 ABEILLE_delta_count
# 10 5 ABEILLE_divergence_score
# 10 5 OUTSINGLE
# 10 5 f0.1L20
# 10 6 OUTRIDER_padjust
# 10 6 ABEILLE_anomaly_score
# 10 6 ABEILLE_delta_count
# 10 6 ABEILLE_divergence_score
# 10 6 OUTSINGLE
# 10 6 f0.1L20
# 10 7 OUTRIDER_padjust
# 10 7 ABEILLE_anomaly_score
# 10 7 ABEILLE_delta_count
# 10 7 ABEILLE_divergence_score
# 10 7 OUTSINGLE
# 10 7 f0.1L20
# 10 8 OUTRIDER_padjust
# 10 8 ABEILLE_anomaly_score
# 10 8 ABEILLE_delta_count
# 10 8 ABEILLE_divergence_score
# 10 8 OUTSINGLE
# 10 8 f0.1L20
# 10 9 OUTRIDER_padjust
# 10 9 ABEILLE_anomaly_score
# 10 9 ABEILLE_delta_count
# 10 9 ABEILLE_divergence_score
# 10 9 OUTSINGLE
# 10 9 f0.1L20
# 30 0 OUTRIDER_padjust
# 30 0 ABEILLE_anomaly_score
# 30 0 ABEILLE_delta_count
# 30 0 ABEILLE_divergence_score
# 30 0 OUTSINGLE
# 30 0 f0.1L20
# 30 1 OUTRIDER_padjust
# 30 1 ABEILLE_anomaly_score
# 30 1 ABEILLE_delta_count
# 30 1 ABEILLE_divergence_score
# 30 1 OUTSINGLE
# 30 1 f0.1L20
# 30 2 OUTRIDER_padjust
# 30 2 ABEILLE_anomaly_score
# 30 2 ABEILLE_delta_count
# 30 2 ABEILLE_divergence_score
# 30 2 OUTSINGLE
# 30 2 f0.1L20
# 30 3 OUTRIDER_padjust
# 30 3 ABEILLE_anomaly_score
# 30 3 ABEILLE_delta_count
# 30 3 ABEILLE_divergence_score
# 30 3 OUTSINGLE
# 30 3 f0.1L20
# 30 4 OUTRIDER_padjust
# 30 4 ABEILLE_anomaly_score
# 30 4 ABEILLE_delta_count
# 30 4 ABEILLE_divergence_score
# 30 4 OUTSINGLE
# 30 4 f0.1L20
# 30 5 OUTRIDER_padjust
# 30 5 ABEILLE_anomaly_score
# 30 5 ABEILLE_delta_count
# 30 5 ABEILLE_divergence_score
# 30 5 OUTSINGLE
# 30 5 f0.1L20
# 30 6 OUTRIDER_padjust
# 30 6 ABEILLE_anomaly_score
# 30 6 ABEILLE_delta_count
# 30 6 ABEILLE_divergence_score
# 30 6 OUTSINGLE
# 30 6 f0.1L20
# 30 7 OUTRIDER_padjust
# 30 7 ABEILLE_anomaly_score
# 30 7 ABEILLE_delta_count
# 30 7 ABEILLE_divergence_score
# 30 7 OUTSINGLE
# 30 7 f0.1L20
# 30 8 OUTRIDER_padjust
# 30 8 ABEILLE_anomaly_score
# 30 8 ABEILLE_delta_count
# 30 8 ABEILLE_divergence_score
# 30 8 OUTSINGLE
# 30 8 f0.1L20
# 30 9 OUTRIDER_padjust
# 30 9 ABEILLE_anomaly_score
# 30 9 ABEILLE_delta_count
# 30 9 ABEILLE_divergence_score
# 30 9 OUTSINGLE
# 30 9 f0.1L20
# 60 0 OUTRIDER_padjust
# 60 0 ABEILLE_anomaly_score
# 60 0 ABEILLE_delta_count
# 60 0 ABEILLE_divergence_score
# 60 0 OUTSINGLE
# 60 0 f0.1L20
# 60 1 OUTRIDER_padjust
# 60 1 ABEILLE_anomaly_score
# 60 1 ABEILLE_delta_count
# 60 1 ABEILLE_divergence_score
# 60 1 OUTSINGLE
# 60 1 f0.1L20
# 60 2 OUTRIDER_padjust
# 60 2 ABEILLE_anomaly_score
# 60 2 ABEILLE_delta_count
# 60 2 ABEILLE_divergence_score
# 60 2 OUTSINGLE
# 60 2 f0.1L20
# 60 3 OUTRIDER_padjust
# 60 3 ABEILLE_anomaly_score
# 60 3 ABEILLE_delta_count
# 60 3 ABEILLE_divergence_score
# 60 3 OUTSINGLE
# 60 3 f0.1L20
# 60 4 OUTRIDER_padjust
# 60 4 ABEILLE_anomaly_score
# 60 4 ABEILLE_delta_count
# 60 4 ABEILLE_divergence_score
# 60 4 OUTSINGLE
# 60 4 f0.1L20
# 60 5 OUTRIDER_padjust
# 60 5 ABEILLE_anomaly_score
# 60 5 ABEILLE_delta_count
# 60 5 ABEILLE_divergence_score
# 60 5 OUTSINGLE
# 60 5 f0.1L20
# 60 6 OUTRIDER_padjust
# 60 6 ABEILLE_anomaly_score
# 60 6 ABEILLE_delta_count
# 60 6 ABEILLE_divergence_score
# 60 6 OUTSINGLE
# 60 6 f0.1L20
# 60 7 OUTRIDER_padjust
# 60 7 ABEILLE_anomaly_score
# 60 7 ABEILLE_delta_count
# 60 7 ABEILLE_divergence_score
# 60 7 OUTSINGLE
# 60 7 f0.1L20
# 60 8 OUTRIDER_padjust
# 60 8 ABEILLE_anomaly_score
# 60 8 ABEILLE_delta_count
# 60 8 ABEILLE_divergence_score
# 60 8 OUTSINGLE
# 60 8 f0.1L20
# 60 9 OUTRIDER_padjust
# 60 9 ABEILLE_anomaly_score
# 60 9 ABEILLE_delta_count
# 60 9 ABEILLE_divergence_score
# 60 9 OUTSINGLE
# 60 9 f0.1L20
# 100 0 OUTRIDER_padjust
# 100 0 ABEILLE_anomaly_score
# 100 0 ABEILLE_delta_count
# 100 0 ABEILLE_divergence_score
# 100 0 OUTSINGLE
# 100 0 f0.1L20
# 100 1 OUTRIDER_padjust
# 100 1 ABEILLE_anomaly_score
# 100 1 ABEILLE_delta_count
# 100 1 ABEILLE_divergence_score
# 100 1 OUTSINGLE
# 100 1 f0.1L20
# 100 2 OUTRIDER_padjust
# 100 2 ABEILLE_anomaly_score
# 100 2 ABEILLE_delta_count
# 100 2 ABEILLE_divergence_score
# 100 2 OUTSINGLE
# 100 2 f0.1L20
# 100 3 OUTRIDER_padjust
# 100 3 ABEILLE_anomaly_score
# 100 3 ABEILLE_delta_count
# 100 3 ABEILLE_divergence_score
# 100 3 OUTSINGLE
# 100 3 f0.1L20
# 100 4 OUTRIDER_padjust
# 100 4 ABEILLE_anomaly_score
# 100 4 ABEILLE_delta_count
# 100 4 ABEILLE_divergence_score
# 100 4 OUTSINGLE
# 100 4 f0.1L20
# 100 5 OUTRIDER_padjust
# 100 5 ABEILLE_anomaly_score
# 100 5 ABEILLE_delta_count
# 100 5 ABEILLE_divergence_score
# 100 5 OUTSINGLE
# 100 5 f0.1L20
# 100 6 OUTRIDER_padjust
# 100 6 ABEILLE_anomaly_score
# 100 6 ABEILLE_delta_count
# 100 6 ABEILLE_divergence_score
# 100 6 OUTSINGLE
# 100 6 f0.1L20
# 100 7 OUTRIDER_padjust
# 100 7 ABEILLE_anomaly_score
# 100 7 ABEILLE_delta_count
# 100 7 ABEILLE_divergence_score
# 100 7 OUTSINGLE
# 100 7 f0.1L20
# 100 8 OUTRIDER_padjust
# 100 8 ABEILLE_anomaly_score
# 100 8 ABEILLE_delta_count
# 100 8 ABEILLE_divergence_score
# 100 8 OUTSINGLE
# 100 8 f0.1L20
# 100 9 OUTRIDER_padjust
# 100 9 ABEILLE_anomaly_score
# 100 9 ABEILLE_delta_count
# 100 9 ABEILLE_divergence_score
# 100 9 OUTSINGLE
# 100 9 f0.1L20

# %%
# dict_curve[0]['OUTSINGLE'][0] == dict_curve[0]['ABEILLE_delta_count'][0]

# %%
draw_methods = methods

for i, tissue_data in tissues.iterrows():
    # tissue_data = tissues.iloc[0]
    t = tissue_data['TISSUE_ID']  # TISSUE_ID
    tn = tissue_data['TISSUE_NAME']  # TISSUE_NAME
    ns = tissue_data['N_SAMPLE']  # N_SAMPLE
    ng = tissue_data['N_GENE']  # N_GENE

    # 创建基础前缀
    name_prefix = f't{i:02d}_{t}_s{ns}_g{ng}' # id, number of samples, number of genes.
    print(name_prefix)

    fig, axes = plt.subplots(1, len(sample_sizes), figsize=(4*len(sample_sizes), 3), sharey=True )
    myindex = pd.MultiIndex.from_tuples([ (size, k) for size in sample_sizes for k in range(n_replicates) ],names=['size', 'seed'])
    auprc =  pd.DataFrame(index= myindex, columns=draw_methods, dtype=np.float32)

    for i, size in enumerate(sample_sizes):
        
        # file = f'{metric_output_path}/t{i:02d}_{t}_auprc.pkl'
        file = f'{metric_output_path}/{name_prefix}_size_{size}_rank{phase}.pkl'
        with open(file,'rb') as f:
            data_load = pickle.load(f)
        _t, _tn, _i, dict_curve = data_load[0], data_load[1], data_load[2], data_load[3]
            
        required_sets = 1
        max_bin = 50
        bins = list(range(0, max_bin + 1)) + [20000]
        nice_names = list(range(1,max_bin + 1))+[20000]#[ f'{x}%' for x in bins[:-1]]

        draw = \
        pd.concat([
        pd.concat( [ 
            pd.concat( [ (dict_curve[k][m][j]['rank']).value_counts(bins = bins, sort=False) for j in range(required_sets)],
                    axis=0, keys= range(required_sets))
            for m in draw_methods ], axis=0, keys=draw_methods, names=['method'])
        for k in range(n_replicates)], axis = 0, keys=range(n_replicates),names=['rep']).reset_index()
        draw['rank'] = nice_names * len(draw_methods) * n_replicates
        draw = draw.query('rank < 10000').copy()
        draw['recall'] = draw.groupby(['method','rep'])['count'].cumsum()/len(df_outlier)

        sns.lineplot(
            data=draw,
            x="rank",
            y="recall",
            hue="method",
            palette='tab10',
            ax=axes[i],
            errorbar=('ci', 95),  # 90%置信区间
            n_boot=100,  # bootstrap采样次数
            alpha=1,
        )
        axes[i].set_title(f'Sample Size: {size}')
        #     # 1. 去掉子图自己的图例
        axes[i].get_legend().remove()

    handles, labels = axes[-1].get_legend_handles_labels()
    fig.legend(handles, labels,
            loc='center',           # 居中
            bbox_to_anchor=(0.5, 0.02),  # 放在底部（微调 0.02）
            ncol=len(labels),       # 横向排列
            frameon=True)

    plt.tight_layout()
    # 给图例留一点底部空间
    fig.subplots_adjust(bottom=0.2)
    fig.suptitle(name_prefix, y=1.02, fontsize=14, fontweight='bold')
# Out:
# t00_FBSS_s269_g12369
# t01_FBNS_s154_g13411

# %%
## PCT
list_outlier_pct = [ 0.04, 0.08, 0.16, 0.24, 0.32, 0.40 ]
sample_sizes = [50,]
list_outlier_pct = [ 0.04, 0.08, 0.16, 0.24,]
sample_sizes = [100,]
# 从tissues中获取信息
for i, tissue_data in tissues.iterrows():
    # tissue_data = tissues.iloc[0]
    t = tissue_data['TISSUE_ID']  # TISSUE_ID
    tn = tissue_data['TISSUE_NAME']  # TISSUE_NAME
    ns = tissue_data['N_SAMPLE']  # N_SAMPLE
    ng = tissue_data['N_GENE']  # N_GENE
    ctsfile = tissue_data['CTS_FILE']  # CTS_FILE
    outlierfile = tissue_data['OUTLIER_FILE']  # OUTLIER_FILE
    
    # positive samples
    outlier = pd.read_csv(outlierfile.replace('.tsv', f'{phase}.tsv'), sep='\t', index_col=0)
    assert outlier['Sample'].size == len(set(outlier['Sample']))
    outliers_used = outlier.copy()
    
    for pct in list_outlier_pct: # 增加pct的变化
        # 创建基础前缀
        name_prefix = f't{i:02d}_{t}_s{ns}_g{ng}_pct{pct:.2f}'
        print(name_prefix)
        output_file = f'{task_config_path}/{name_prefix}_sampled_configs_dict.pkl'
        sampled_configs = pickle.load(open(output_file, 'rb'))

        for size in sample_sizes:
            
            dict_res = dict() # size
            dict_curve = dict()
            
            for seed in range(n_replicates):
                k = seed
                dict_res[k] = dict() # 10 seeds 
                dict_curve[k] = dict()
                # 获取当前抽样的配置
                current_config = sampled_configs[f'size_{size}'][f'seed_{seed}']
                task_config = current_config['config']
                samples_used = current_config['selected_samples']
                df_outlier = outliers_used.query('(Sample in @samples_used)').copy()
                
                for m in methods:
                    # ==> level 3. (tissue, task, method)
                    print(size, seed, m, pct)
                    dict_curve[k][m] = dict()
                
                    for j,row in task_config.iterrows():                    
                        if m.startswith('ABEILLE'):
                            method, score_col = m.split('_',1)
                            res_data = pd.read_csv(f"{row[method]}_raw.gz", sep='\t',index_col=0)
                            res_data.index = [(s,g) for s,g in zip(res_data['Sample'], res_data['Transcript'])]
                            class_col = 'predict'
                            gene_col = 'Transcript'
                            sample_col = 'Sample'
                            dict_curve[k][m][j] = pivot_sort_score_outlier_rank(res_data, score_col, gene_col, sample_col, df_outlier)
                                    
                        elif m.startswith('OUTRIDER'):
                            method, score_col = m.split('_',1)
                            res_data = pd.read_csv(f"{row[method]}_raw.gz", sep='\t',index_col=0)
                            res_data.index = [(s,g) for s,g in zip(res_data['sampleID'], res_data['geneID'])]
                            class_col = 'aberrant'
                            gene_col = 'geneID'
                            sample_col = 'sampleID'
                            dict_curve[k][m][j] = pivot_sort_score_outlier_rank(res_data, score_col, gene_col, sample_col, df_outlier)
                        
                        elif m == 'OUTSINGLE':
                            df_pred = pd.read_csv(f"{row[m]}", sep='\t',index_col=0)
                            dict_curve[k][m][j] = sort_score_outlier_rank(df_pred, df_outlier)  
                                                    
                        else: # my method
                            df_pred = pd.read_csv(f'{row['MyMethod']}_res_{m}.txt.gz', sep='\t',index_col=0)
                            dict_curve[k][m][j] = sort_score_outlier_rank(df_pred, df_outlier)
                                                        
            file = f'{metric_output_path}/{name_prefix}_size_{size}_rank{phase}.pkl'
            outputdata = [ t, tn, i, dict_curve ]        
                                    
            import pickle
            with open(file, 'wb') as f: 
                pickle.dump( outputdata,  f )
# Out:
# t00_FBSS_s269_g12369_pct0.04
# 100 0 OUTRIDER_padjust 0.04
# 100 0 ABEILLE_anomaly_score 0.04
# 100 0 ABEILLE_delta_count 0.04
# 100 0 ABEILLE_divergence_score 0.04
# 100 0 OUTSINGLE 0.04
# 100 0 f0.1L20 0.04
# 100 1 OUTRIDER_padjust 0.04
# 100 1 ABEILLE_anomaly_score 0.04
# 100 1 ABEILLE_delta_count 0.04
# 100 1 ABEILLE_divergence_score 0.04
# 100 1 OUTSINGLE 0.04
# 100 1 f0.1L20 0.04
# 100 2 OUTRIDER_padjust 0.04
# 100 2 ABEILLE_anomaly_score 0.04
# 100 2 ABEILLE_delta_count 0.04
# 100 2 ABEILLE_divergence_score 0.04
# 100 2 OUTSINGLE 0.04
# 100 2 f0.1L20 0.04
# 100 3 OUTRIDER_padjust 0.04
# 100 3 ABEILLE_anomaly_score 0.04
# 100 3 ABEILLE_delta_count 0.04
# 100 3 ABEILLE_divergence_score 0.04
# 100 3 OUTSINGLE 0.04
# 100 3 f0.1L20 0.04
# 100 4 OUTRIDER_padjust 0.04
# 100 4 ABEILLE_anomaly_score 0.04
# 100 4 ABEILLE_delta_count 0.04
# 100 4 ABEILLE_divergence_score 0.04
# 100 4 OUTSINGLE 0.04
# 100 4 f0.1L20 0.04
# 100 5 OUTRIDER_padjust 0.04
# 100 5 ABEILLE_anomaly_score 0.04
# 100 5 ABEILLE_delta_count 0.04
# 100 5 ABEILLE_divergence_score 0.04
# 100 5 OUTSINGLE 0.04
# 100 5 f0.1L20 0.04
# 100 6 OUTRIDER_padjust 0.04
# 100 6 ABEILLE_anomaly_score 0.04
# 100 6 ABEILLE_delta_count 0.04
# 100 6 ABEILLE_divergence_score 0.04
# 100 6 OUTSINGLE 0.04
# 100 6 f0.1L20 0.04
# 100 7 OUTRIDER_padjust 0.04
# 100 7 ABEILLE_anomaly_score 0.04
# 100 7 ABEILLE_delta_count 0.04
# 100 7 ABEILLE_divergence_score 0.04
# 100 7 OUTSINGLE 0.04
# 100 7 f0.1L20 0.04
# 100 8 OUTRIDER_padjust 0.04
# 100 8 ABEILLE_anomaly_score 0.04
# 100 8 ABEILLE_delta_count 0.04
# 100 8 ABEILLE_divergence_score 0.04
# 100 8 OUTSINGLE 0.04
# 100 8 f0.1L20 0.04
# 100 9 OUTRIDER_padjust 0.04
# 100 9 ABEILLE_anomaly_score 0.04
# 100 9 ABEILLE_delta_count 0.04
# 100 9 ABEILLE_divergence_score 0.04
# 100 9 OUTSINGLE 0.04
# 100 9 f0.1L20 0.04
# t00_FBSS_s269_g12369_pct0.08
# 100 0 OUTRIDER_padjust 0.08
# 100 0 ABEILLE_anomaly_score 0.08
# 100 0 ABEILLE_delta_count 0.08
# 100 0 ABEILLE_divergence_score 0.08
# 100 0 OUTSINGLE 0.08
# 100 0 f0.1L20 0.08
# 100 1 OUTRIDER_padjust 0.08
# 100 1 ABEILLE_anomaly_score 0.08
# 100 1 ABEILLE_delta_count 0.08
# 100 1 ABEILLE_divergence_score 0.08
# 100 1 OUTSINGLE 0.08
# 100 1 f0.1L20 0.08
# 100 2 OUTRIDER_padjust 0.08
# 100 2 ABEILLE_anomaly_score 0.08
# 100 2 ABEILLE_delta_count 0.08
# 100 2 ABEILLE_divergence_score 0.08
# 100 2 OUTSINGLE 0.08
# 100 2 f0.1L20 0.08
# 100 3 OUTRIDER_padjust 0.08
# 100 3 ABEILLE_anomaly_score 0.08
# 100 3 ABEILLE_delta_count 0.08
# 100 3 ABEILLE_divergence_score 0.08
# 100 3 OUTSINGLE 0.08
# 100 3 f0.1L20 0.08
# 100 4 OUTRIDER_padjust 0.08
# 100 4 ABEILLE_anomaly_score 0.08
# 100 4 ABEILLE_delta_count 0.08
# 100 4 ABEILLE_divergence_score 0.08
# 100 4 OUTSINGLE 0.08
# 100 4 f0.1L20 0.08
# 100 5 OUTRIDER_padjust 0.08
# 100 5 ABEILLE_anomaly_score 0.08
# 100 5 ABEILLE_delta_count 0.08
# 100 5 ABEILLE_divergence_score 0.08
# 100 5 OUTSINGLE 0.08
# 100 5 f0.1L20 0.08
# 100 6 OUTRIDER_padjust 0.08
# 100 6 ABEILLE_anomaly_score 0.08
# 100 6 ABEILLE_delta_count 0.08
# 100 6 ABEILLE_divergence_score 0.08
# 100 6 OUTSINGLE 0.08
# 100 6 f0.1L20 0.08
# 100 7 OUTRIDER_padjust 0.08
# 100 7 ABEILLE_anomaly_score 0.08
# 100 7 ABEILLE_delta_count 0.08
# 100 7 ABEILLE_divergence_score 0.08
# 100 7 OUTSINGLE 0.08
# 100 7 f0.1L20 0.08
# 100 8 OUTRIDER_padjust 0.08
# 100 8 ABEILLE_anomaly_score 0.08
# 100 8 ABEILLE_delta_count 0.08
# 100 8 ABEILLE_divergence_score 0.08
# 100 8 OUTSINGLE 0.08
# 100 8 f0.1L20 0.08
# 100 9 OUTRIDER_padjust 0.08
# 100 9 ABEILLE_anomaly_score 0.08
# 100 9 ABEILLE_delta_count 0.08
# 100 9 ABEILLE_divergence_score 0.08
# 100 9 OUTSINGLE 0.08
# 100 9 f0.1L20 0.08
# t00_FBSS_s269_g12369_pct0.16
# 100 0 OUTRIDER_padjust 0.16
# 100 0 ABEILLE_anomaly_score 0.16
# 100 0 ABEILLE_delta_count 0.16
# 100 0 ABEILLE_divergence_score 0.16
# 100 0 OUTSINGLE 0.16
# 100 0 f0.1L20 0.16
# 100 1 OUTRIDER_padjust 0.16
# 100 1 ABEILLE_anomaly_score 0.16
# 100 1 ABEILLE_delta_count 0.16
# 100 1 ABEILLE_divergence_score 0.16
# 100 1 OUTSINGLE 0.16
# 100 1 f0.1L20 0.16
# 100 2 OUTRIDER_padjust 0.16
# 100 2 ABEILLE_anomaly_score 0.16
# 100 2 ABEILLE_delta_count 0.16
# 100 2 ABEILLE_divergence_score 0.16
# 100 2 OUTSINGLE 0.16
# 100 2 f0.1L20 0.16
# 100 3 OUTRIDER_padjust 0.16
# 100 3 ABEILLE_anomaly_score 0.16
# 100 3 ABEILLE_delta_count 0.16
# 100 3 ABEILLE_divergence_score 0.16
# 100 3 OUTSINGLE 0.16
# 100 3 f0.1L20 0.16
# 100 4 OUTRIDER_padjust 0.16
# 100 4 ABEILLE_anomaly_score 0.16
# 100 4 ABEILLE_delta_count 0.16
# 100 4 ABEILLE_divergence_score 0.16
# 100 4 OUTSINGLE 0.16
# 100 4 f0.1L20 0.16
# 100 5 OUTRIDER_padjust 0.16
# 100 5 ABEILLE_anomaly_score 0.16
# 100 5 ABEILLE_delta_count 0.16
# 100 5 ABEILLE_divergence_score 0.16
# 100 5 OUTSINGLE 0.16
# 100 5 f0.1L20 0.16
# 100 6 OUTRIDER_padjust 0.16
# 100 6 ABEILLE_anomaly_score 0.16
# 100 6 ABEILLE_delta_count 0.16
# 100 6 ABEILLE_divergence_score 0.16
# 100 6 OUTSINGLE 0.16
# 100 6 f0.1L20 0.16
# 100 7 OUTRIDER_padjust 0.16
# 100 7 ABEILLE_anomaly_score 0.16
# 100 7 ABEILLE_delta_count 0.16
# 100 7 ABEILLE_divergence_score 0.16
# 100 7 OUTSINGLE 0.16
# 100 7 f0.1L20 0.16
# 100 8 OUTRIDER_padjust 0.16
# 100 8 ABEILLE_anomaly_score 0.16
# 100 8 ABEILLE_delta_count 0.16
# 100 8 ABEILLE_divergence_score 0.16
# 100 8 OUTSINGLE 0.16
# 100 8 f0.1L20 0.16
# 100 9 OUTRIDER_padjust 0.16
# 100 9 ABEILLE_anomaly_score 0.16
# 100 9 ABEILLE_delta_count 0.16
# 100 9 ABEILLE_divergence_score 0.16
# 100 9 OUTSINGLE 0.16
# 100 9 f0.1L20 0.16
# t00_FBSS_s269_g12369_pct0.24
# 100 0 OUTRIDER_padjust 0.24
# 100 0 ABEILLE_anomaly_score 0.24
# 100 0 ABEILLE_delta_count 0.24
# 100 0 ABEILLE_divergence_score 0.24
# 100 0 OUTSINGLE 0.24
# 100 0 f0.1L20 0.24
# 100 1 OUTRIDER_padjust 0.24
# 100 1 ABEILLE_anomaly_score 0.24
# 100 1 ABEILLE_delta_count 0.24
# 100 1 ABEILLE_divergence_score 0.24
# 100 1 OUTSINGLE 0.24
# 100 1 f0.1L20 0.24
# 100 2 OUTRIDER_padjust 0.24
# 100 2 ABEILLE_anomaly_score 0.24
# 100 2 ABEILLE_delta_count 0.24
# 100 2 ABEILLE_divergence_score 0.24
# 100 2 OUTSINGLE 0.24
# 100 2 f0.1L20 0.24
# 100 3 OUTRIDER_padjust 0.24
# 100 3 ABEILLE_anomaly_score 0.24
# 100 3 ABEILLE_delta_count 0.24
# 100 3 ABEILLE_divergence_score 0.24
# 100 3 OUTSINGLE 0.24
# 100 3 f0.1L20 0.24
# 100 4 OUTRIDER_padjust 0.24
# 100 4 ABEILLE_anomaly_score 0.24
# 100 4 ABEILLE_delta_count 0.24
# 100 4 ABEILLE_divergence_score 0.24
# 100 4 OUTSINGLE 0.24
# 100 4 f0.1L20 0.24
# 100 5 OUTRIDER_padjust 0.24
# 100 5 ABEILLE_anomaly_score 0.24
# 100 5 ABEILLE_delta_count 0.24
# 100 5 ABEILLE_divergence_score 0.24
# 100 5 OUTSINGLE 0.24
# 100 5 f0.1L20 0.24
# 100 6 OUTRIDER_padjust 0.24
# 100 6 ABEILLE_anomaly_score 0.24
# 100 6 ABEILLE_delta_count 0.24
# 100 6 ABEILLE_divergence_score 0.24
# 100 6 OUTSINGLE 0.24
# 100 6 f0.1L20 0.24
# 100 7 OUTRIDER_padjust 0.24
# 100 7 ABEILLE_anomaly_score 0.24
# 100 7 ABEILLE_delta_count 0.24
# 100 7 ABEILLE_divergence_score 0.24
# 100 7 OUTSINGLE 0.24
# 100 7 f0.1L20 0.24
# 100 8 OUTRIDER_padjust 0.24
# 100 8 ABEILLE_anomaly_score 0.24
# 100 8 ABEILLE_delta_count 0.24
# 100 8 ABEILLE_divergence_score 0.24
# 100 8 OUTSINGLE 0.24
# 100 8 f0.1L20 0.24
# 100 9 OUTRIDER_padjust 0.24
# 100 9 ABEILLE_anomaly_score 0.24
# 100 9 ABEILLE_delta_count 0.24
# 100 9 ABEILLE_divergence_score 0.24
# 100 9 OUTSINGLE 0.24
# 100 9 f0.1L20 0.24
# t01_FBNS_s154_g13411_pct0.04
# 100 0 OUTRIDER_padjust 0.04
# 100 0 ABEILLE_anomaly_score 0.04
# 100 0 ABEILLE_delta_count 0.04
# 100 0 ABEILLE_divergence_score 0.04
# 100 0 OUTSINGLE 0.04
# 100 0 f0.1L20 0.04
# 100 1 OUTRIDER_padjust 0.04
# 100 1 ABEILLE_anomaly_score 0.04
# 100 1 ABEILLE_delta_count 0.04
# 100 1 ABEILLE_divergence_score 0.04
# 100 1 OUTSINGLE 0.04
# 100 1 f0.1L20 0.04
# 100 2 OUTRIDER_padjust 0.04
# 100 2 ABEILLE_anomaly_score 0.04
# 100 2 ABEILLE_delta_count 0.04
# 100 2 ABEILLE_divergence_score 0.04
# 100 2 OUTSINGLE 0.04
# 100 2 f0.1L20 0.04
# 100 3 OUTRIDER_padjust 0.04
# 100 3 ABEILLE_anomaly_score 0.04
# 100 3 ABEILLE_delta_count 0.04
# 100 3 ABEILLE_divergence_score 0.04
# 100 3 OUTSINGLE 0.04
# 100 3 f0.1L20 0.04
# 100 4 OUTRIDER_padjust 0.04
# 100 4 ABEILLE_anomaly_score 0.04
# 100 4 ABEILLE_delta_count 0.04
# 100 4 ABEILLE_divergence_score 0.04
# 100 4 OUTSINGLE 0.04
# 100 4 f0.1L20 0.04
# 100 5 OUTRIDER_padjust 0.04
# 100 5 ABEILLE_anomaly_score 0.04
# 100 5 ABEILLE_delta_count 0.04
# 100 5 ABEILLE_divergence_score 0.04
# 100 5 OUTSINGLE 0.04
# 100 5 f0.1L20 0.04
# 100 6 OUTRIDER_padjust 0.04
# 100 6 ABEILLE_anomaly_score 0.04
# 100 6 ABEILLE_delta_count 0.04
# 100 6 ABEILLE_divergence_score 0.04
# 100 6 OUTSINGLE 0.04
# 100 6 f0.1L20 0.04
# 100 7 OUTRIDER_padjust 0.04
# 100 7 ABEILLE_anomaly_score 0.04
# 100 7 ABEILLE_delta_count 0.04
# 100 7 ABEILLE_divergence_score 0.04
# 100 7 OUTSINGLE 0.04
# 100 7 f0.1L20 0.04
# 100 8 OUTRIDER_padjust 0.04
# 100 8 ABEILLE_anomaly_score 0.04
# 100 8 ABEILLE_delta_count 0.04
# 100 8 ABEILLE_divergence_score 0.04
# 100 8 OUTSINGLE 0.04
# 100 8 f0.1L20 0.04
# 100 9 OUTRIDER_padjust 0.04
# 100 9 ABEILLE_anomaly_score 0.04
# 100 9 ABEILLE_delta_count 0.04
# 100 9 ABEILLE_divergence_score 0.04
# 100 9 OUTSINGLE 0.04
# 100 9 f0.1L20 0.04
# t01_FBNS_s154_g13411_pct0.08
# 100 0 OUTRIDER_padjust 0.08
# 100 0 ABEILLE_anomaly_score 0.08
# 100 0 ABEILLE_delta_count 0.08
# 100 0 ABEILLE_divergence_score 0.08
# 100 0 OUTSINGLE 0.08
# 100 0 f0.1L20 0.08
# 100 1 OUTRIDER_padjust 0.08
# 100 1 ABEILLE_anomaly_score 0.08
# 100 1 ABEILLE_delta_count 0.08
# 100 1 ABEILLE_divergence_score 0.08
# 100 1 OUTSINGLE 0.08
# 100 1 f0.1L20 0.08
# 100 2 OUTRIDER_padjust 0.08
# 100 2 ABEILLE_anomaly_score 0.08
# 100 2 ABEILLE_delta_count 0.08
# 100 2 ABEILLE_divergence_score 0.08
# 100 2 OUTSINGLE 0.08
# 100 2 f0.1L20 0.08
# 100 3 OUTRIDER_padjust 0.08
# 100 3 ABEILLE_anomaly_score 0.08
# 100 3 ABEILLE_delta_count 0.08
# 100 3 ABEILLE_divergence_score 0.08
# 100 3 OUTSINGLE 0.08
# 100 3 f0.1L20 0.08
# 100 4 OUTRIDER_padjust 0.08
# 100 4 ABEILLE_anomaly_score 0.08
# 100 4 ABEILLE_delta_count 0.08
# 100 4 ABEILLE_divergence_score 0.08
# 100 4 OUTSINGLE 0.08
# 100 4 f0.1L20 0.08
# 100 5 OUTRIDER_padjust 0.08
# 100 5 ABEILLE_anomaly_score 0.08
# 100 5 ABEILLE_delta_count 0.08
# 100 5 ABEILLE_divergence_score 0.08
# 100 5 OUTSINGLE 0.08
# 100 5 f0.1L20 0.08
# 100 6 OUTRIDER_padjust 0.08
# 100 6 ABEILLE_anomaly_score 0.08
# 100 6 ABEILLE_delta_count 0.08
# 100 6 ABEILLE_divergence_score 0.08
# 100 6 OUTSINGLE 0.08
# 100 6 f0.1L20 0.08
# 100 7 OUTRIDER_padjust 0.08
# 100 7 ABEILLE_anomaly_score 0.08
# 100 7 ABEILLE_delta_count 0.08
# 100 7 ABEILLE_divergence_score 0.08
# 100 7 OUTSINGLE 0.08
# 100 7 f0.1L20 0.08
# 100 8 OUTRIDER_padjust 0.08
# 100 8 ABEILLE_anomaly_score 0.08
# 100 8 ABEILLE_delta_count 0.08
# 100 8 ABEILLE_divergence_score 0.08
# 100 8 OUTSINGLE 0.08
# 100 8 f0.1L20 0.08
# 100 9 OUTRIDER_padjust 0.08
# 100 9 ABEILLE_anomaly_score 0.08
# 100 9 ABEILLE_delta_count 0.08
# 100 9 ABEILLE_divergence_score 0.08
# 100 9 OUTSINGLE 0.08
# 100 9 f0.1L20 0.08
# t01_FBNS_s154_g13411_pct0.16
# 100 0 OUTRIDER_padjust 0.16
# 100 0 ABEILLE_anomaly_score 0.16
# 100 0 ABEILLE_delta_count 0.16
# 100 0 ABEILLE_divergence_score 0.16
# 100 0 OUTSINGLE 0.16
# 100 0 f0.1L20 0.16
# 100 1 OUTRIDER_padjust 0.16
# 100 1 ABEILLE_anomaly_score 0.16
# 100 1 ABEILLE_delta_count 0.16
# 100 1 ABEILLE_divergence_score 0.16
# 100 1 OUTSINGLE 0.16
# 100 1 f0.1L20 0.16
# 100 2 OUTRIDER_padjust 0.16
# 100 2 ABEILLE_anomaly_score 0.16
# 100 2 ABEILLE_delta_count 0.16
# 100 2 ABEILLE_divergence_score 0.16
# 100 2 OUTSINGLE 0.16
# 100 2 f0.1L20 0.16
# 100 3 OUTRIDER_padjust 0.16
# 100 3 ABEILLE_anomaly_score 0.16
# 100 3 ABEILLE_delta_count 0.16
# 100 3 ABEILLE_divergence_score 0.16
# 100 3 OUTSINGLE 0.16
# 100 3 f0.1L20 0.16
# 100 4 OUTRIDER_padjust 0.16
# 100 4 ABEILLE_anomaly_score 0.16
# 100 4 ABEILLE_delta_count 0.16
# 100 4 ABEILLE_divergence_score 0.16
# 100 4 OUTSINGLE 0.16
# 100 4 f0.1L20 0.16
# 100 5 OUTRIDER_padjust 0.16
# 100 5 ABEILLE_anomaly_score 0.16
# 100 5 ABEILLE_delta_count 0.16
# 100 5 ABEILLE_divergence_score 0.16
# 100 5 OUTSINGLE 0.16
# 100 5 f0.1L20 0.16
# 100 6 OUTRIDER_padjust 0.16
# 100 6 ABEILLE_anomaly_score 0.16
# 100 6 ABEILLE_delta_count 0.16
# 100 6 ABEILLE_divergence_score 0.16
# 100 6 OUTSINGLE 0.16
# 100 6 f0.1L20 0.16
# 100 7 OUTRIDER_padjust 0.16
# 100 7 ABEILLE_anomaly_score 0.16
# 100 7 ABEILLE_delta_count 0.16
# 100 7 ABEILLE_divergence_score 0.16
# 100 7 OUTSINGLE 0.16
# 100 7 f0.1L20 0.16
# 100 8 OUTRIDER_padjust 0.16
# 100 8 ABEILLE_anomaly_score 0.16
# 100 8 ABEILLE_delta_count 0.16
# 100 8 ABEILLE_divergence_score 0.16
# 100 8 OUTSINGLE 0.16
# 100 8 f0.1L20 0.16
# 100 9 OUTRIDER_padjust 0.16
# 100 9 ABEILLE_anomaly_score 0.16
# 100 9 ABEILLE_delta_count 0.16
# 100 9 ABEILLE_divergence_score 0.16
# 100 9 OUTSINGLE 0.16
# 100 9 f0.1L20 0.16
# t01_FBNS_s154_g13411_pct0.24
# 100 0 OUTRIDER_padjust 0.24
# 100 0 ABEILLE_anomaly_score 0.24
# 100 0 ABEILLE_delta_count 0.24
# 100 0 ABEILLE_divergence_score 0.24
# 100 0 OUTSINGLE 0.24
# 100 0 f0.1L20 0.24
# 100 1 OUTRIDER_padjust 0.24
# 100 1 ABEILLE_anomaly_score 0.24
# 100 1 ABEILLE_delta_count 0.24
# 100 1 ABEILLE_divergence_score 0.24
# 100 1 OUTSINGLE 0.24
# 100 1 f0.1L20 0.24
# 100 2 OUTRIDER_padjust 0.24
# 100 2 ABEILLE_anomaly_score 0.24
# 100 2 ABEILLE_delta_count 0.24
# 100 2 ABEILLE_divergence_score 0.24
# 100 2 OUTSINGLE 0.24
# 100 2 f0.1L20 0.24
# 100 3 OUTRIDER_padjust 0.24
# 100 3 ABEILLE_anomaly_score 0.24
# 100 3 ABEILLE_delta_count 0.24
# 100 3 ABEILLE_divergence_score 0.24
# 100 3 OUTSINGLE 0.24
# 100 3 f0.1L20 0.24
# 100 4 OUTRIDER_padjust 0.24
# 100 4 ABEILLE_anomaly_score 0.24
# 100 4 ABEILLE_delta_count 0.24
# 100 4 ABEILLE_divergence_score 0.24
# 100 4 OUTSINGLE 0.24
# 100 4 f0.1L20 0.24
# 100 5 OUTRIDER_padjust 0.24
# 100 5 ABEILLE_anomaly_score 0.24
# 100 5 ABEILLE_delta_count 0.24
# 100 5 ABEILLE_divergence_score 0.24
# 100 5 OUTSINGLE 0.24
# 100 5 f0.1L20 0.24
# 100 6 OUTRIDER_padjust 0.24
# 100 6 ABEILLE_anomaly_score 0.24
# 100 6 ABEILLE_delta_count 0.24
# 100 6 ABEILLE_divergence_score 0.24
# 100 6 OUTSINGLE 0.24
# 100 6 f0.1L20 0.24
# 100 7 OUTRIDER_padjust 0.24
# 100 7 ABEILLE_anomaly_score 0.24
# 100 7 ABEILLE_delta_count 0.24
# 100 7 ABEILLE_divergence_score 0.24
# 100 7 OUTSINGLE 0.24
# 100 7 f0.1L20 0.24
# 100 8 OUTRIDER_padjust 0.24
# 100 8 ABEILLE_anomaly_score 0.24
# 100 8 ABEILLE_delta_count 0.24
# 100 8 ABEILLE_divergence_score 0.24
# 100 8 OUTSINGLE 0.24
# 100 8 f0.1L20 0.24
# 100 9 OUTRIDER_padjust 0.24
# 100 9 ABEILLE_anomaly_score 0.24
# 100 9 ABEILLE_delta_count 0.24
# 100 9 ABEILLE_divergence_score 0.24
# 100 9 OUTSINGLE 0.24
# 100 9 f0.1L20 0.24

# %%
for i, tissue_data in tissues.iterrows():
    # tissue_data = tissues.iloc[0]
    t = tissue_data['TISSUE_ID']  # TISSUE_ID
    tn = tissue_data['TISSUE_NAME']  # TISSUE_NAME
    ns = tissue_data['N_SAMPLE']  # N_SAMPLE
    ng = tissue_data['N_GENE']  # N_GENE

    fig, axes = plt.subplots(1, len(list_outlier_pct), figsize=(3*len(list_outlier_pct), 3), sharey=True )
    myindex = pd.MultiIndex.from_tuples([ (pct, k) for pct in list_outlier_pct for k in range(n_replicates) ],names=['pct', 'seed'])
    auprc =  pd.DataFrame(index= myindex, columns=draw_methods, dtype=np.float32)
    
    # 创建基础前缀
    for ax_i, pct in enumerate(list_outlier_pct): # 增加pct的变化
        # 创建基础前缀
        name_prefix = f't{i:02d}_{t}_s{ns}_g{ng}_pct{pct:.2f}'
        print(name_prefix)

        for _j, size in enumerate(sample_sizes):
                
            file = f'{metric_output_path}/{name_prefix}_size_{size}_rank{phase}.pkl'
            with open(file,'rb') as f:
                data_load = pickle.load(f)
            _t, _tn, _i, dict_curve = data_load[0], data_load[1], data_load[2], data_load[3]
                
            required_sets = 1
            max_bin = 10
            bins = list(range(0, max_bin + 1)) + [20000]
            nice_names = list(range(1,max_bin + 1))+[20000]#[ f'{x}%' for x in bins[:-1]]

            draw = \
            pd.concat([
            pd.concat( [ 
                pd.concat( [ (dict_curve[k][m][j]['rank']).value_counts(bins = bins, sort=False) for j in range(required_sets)],
                        axis=0, keys= range(required_sets))
                for m in draw_methods ], axis=0, keys=draw_methods, names=['method'])
            for k in range(n_replicates)], axis = 0, keys=range(n_replicates),names=['rep']).reset_index()
            draw['rank'] = nice_names * len(draw_methods) * n_replicates
            draw = draw.query('rank < 10000').copy()
            draw['recall'] = draw.groupby(['method','rep'])['count'].cumsum()/len(df_outlier)                
            
            sns.lineplot(
                data=draw,
                x="rank",
                y="recall",
                hue="method",
                palette='tab10',
                ax=axes[ax_i],
                errorbar=('ci', 95),  # 90%置信区间
                n_boot=100,  # bootstrap采样次数
                alpha=1,
            )
            axes[ax_i].set_title(f'Percent: {pct}')
                # 1. 去掉子图自己的图例
            axes[ax_i].get_legend().remove()

    # 2. 用最后一根轴的“handles/labels”生成 Figure 级图例
    handles, labels = axes[-1].get_legend_handles_labels()
    fig.legend(handles, labels,
            loc='center',           # 居中
            bbox_to_anchor=(0.5, 0.02),  # 放在底部（微调 0.02）
            ncol=len(labels),       # 横向排列
            frameon=True)

    plt.tight_layout()
    # 给图例留一点底部空间
    fig.subplots_adjust(bottom=0.2)
    tissuse_title = f't{i:02d}_{t}_s{ns}_g{ng}'
    fig.suptitle(tissuse_title, y=1.02, fontsize=14, fontweight='bold')
# Out:
# t00_FBSS_s269_g12369_pct0.04
# t00_FBSS_s269_g12369_pct0.08
# t00_FBSS_s269_g12369_pct0.16
# t00_FBSS_s269_g12369_pct0.24
# t01_FBNS_s154_g13411_pct0.04
# t01_FBNS_s154_g13411_pct0.08
# t01_FBNS_s154_g13411_pct0.16
# t01_FBNS_s154_g13411_pct0.24
